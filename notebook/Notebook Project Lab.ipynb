# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Laporan Stock Gudang Darurat 27 April 2021-REV.xlsx')
df.head()
# Out:
#      Tanggal IN / OUT Nomor GDN/GRN Gudang         Dari/Kepada-Masking  \
# 0 2020-02-01       IN         01.01     G2  Gudang Regional PMI_Serang
# 1 2020-02-01      OUT         01.01     G2                  Ketua Umum
# 2 2020-02-01      OUT         01.02     G2        PMI Kabupaten Natuna
# 3 2020-02-05      OUT         05.01     G2       Palang Merah Hongkong
# 4 2020-02-05      OUT         05.02     G2                   Lain-lain
#
#     Nama Barang Merk/Jenis-Deleted Satuan     Masuk   Keluar     Nilai  \
# 0  Masker Bedah              Sensi    Pcs  350000.0      NaN    7000.0
# 1    Masker N95                 3M    Pcs       NaN    800.0  108240.0
# 2  Masker Bedah              Sensi    Pcs       NaN  20000.0    7000.0
# 3  Masker Bedah              Sensi    Pcs       NaN  50000.0    7000.0
# 4  Masker Bedah              Sensi    Pcs       NaN   4000.0    7000.0
#
#          Jumlah  Berat  Total Berat
# 0  2.450000e+09  0.006       2100.0
# 1  8.659200e+07   0.04         32.0
# ...

# %%
df2 = df.rename(columns = {
    'IN / OUT': 'IN/OUT',
    'Dari/Kepada-Masking': 'Dari/Kepada',
    'Merk/Jenis-Deleted': 'Merk/Jenis',
    'Berat': 'Berat Barang',
    'Total Berat': 'Total Berat Barang'
}, inplace = False)
df2.head()
# Out:
#      Tanggal IN/OUT Nomor GDN/GRN Gudang                 Dari/Kepada  \
# 0 2020-02-01     IN         01.01     G2  Gudang Regional PMI_Serang
# 1 2020-02-01    OUT         01.01     G2                  Ketua Umum
# 2 2020-02-01    OUT         01.02     G2        PMI Kabupaten Natuna
# 3 2020-02-05    OUT         05.01     G2       Palang Merah Hongkong
# 4 2020-02-05    OUT         05.02     G2                   Lain-lain
#
#     Nama Barang Merk/Jenis Satuan     Masuk   Keluar     Nilai        Jumlah  \
# 0  Masker Bedah      Sensi    Pcs  350000.0      NaN    7000.0  2.450000e+09
# 1    Masker N95         3M    Pcs       NaN    800.0  108240.0  8.659200e+07
# 2  Masker Bedah      Sensi    Pcs       NaN  20000.0    7000.0  1.400000e+08
# 3  Masker Bedah      Sensi    Pcs       NaN  50000.0    7000.0  3.500000e+08
# 4  Masker Bedah      Sensi    Pcs       NaN   4000.0    7000.0  2.800000e+07
#
#   Berat Barang  Total Berat Barang
# 0        0.006              2100.0
# ...

# %%
df3 = df2.copy()
df3 = df3.replace(r'^\s*$',np.NaN, regex=True)

# %%
df3['Berat Barang'] = df3['Berat Barang'].replace(',','.',regex=True).astype(float)

# %%
df3[['IN/OUT','Nama Barang','Merk/Jenis','Nomor GDN/GRN']] = df3[['IN/OUT','Nama Barang','Merk/Jenis','Nomor GDN/GRN']].astype(str)

# %%
df4 = df3.copy()
df4['Berat Barang'] = df4['Berat Barang'].astype(str)
df4['Nilai'] = df4['Nilai'].astype(str)

# %%
df4['Nama Barang'] = df4['Nama Barang'].apply(lambda x: x.lower().strip())
df4['Merk/Jenis'] = df4['Merk/Jenis'].apply(lambda x: x.lower().strip())

# %%
#obat
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('nan', str(x['Nama Barang']).split('-')[1]) 
                            if 'obat' in x['Nama Barang'] 
                            else x['Merk/Jenis'], 
                            axis=1)
df4['Nama Barang']=df4['Nama Barang'].apply(lambda x:x.split('-')[0] 
                                            if 'obat' in x 
                                            else x)

# %%
#vitamin
df4['Merk/Jenis'] = df4.apply(lambda x: x['Merk/Jenis'].replace('nan', str(x['Nama Barang']).split('-')[1]) 
                              if 'vitamin' in x['Nama Barang'] 
                              else x['Merk/Jenis'],
                              axis=1)
df4['Nama Barang'] = df4['Nama Barang'].apply(lambda x: x.split()[0] 
                                              if 'vitamin' in x 
                                              else x)

# %%
#suplemen
df4['Merk/Jenis'] = df4.apply(lambda x: x['Merk/Jenis'].replace('nan', str(x['Nama Barang']).split('-')[1]) 
                              if 'suplemen' in x['Nama Barang'] 
                              else x['Merk/Jenis'],
                              axis=1)
df4['Nama Barang'] = df4['Nama Barang'].apply(lambda x: x.split()[0] 
                                              if 'suplemen' in x 
                                              else x)
#hemaviton -> suplemen
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('nan', str(x['Nama Barang'])) 
                            if 'hemaviton' in x['Nama Barang'] 
                            else x['Merk/Jenis'], 
                            axis=1)
df4['Nama Barang']=df4['Nama Barang'].apply(lambda x:'suplemen' 
                                            if 'hemaviton' in x 
                                            else x)

# %%
#biskuit sari gandum
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('nan', str(x['Nama Barang']).split(' ', 1)[1]) 
                            if 'biskuit sari gandum' in x['Nama Barang'] 
                            else x['Merk/Jenis'], 
                            axis=1)
#biskuit
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('nan', str(x['Nama Barang']).split()[1]) 
                            if 'biskuit' in x['Nama Barang'] 
                            else x['Merk/Jenis'], 
                            axis=1)
df4['Nama Barang']=df4['Nama Barang'].apply(lambda x:x.split()[0] 
                                            if 'biskuit' in x 
                                            else x)
#roma malkies -> biskuit
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('nan', str(x['Nama Barang'])) 
                            if 'roma malkies' in x['Nama Barang'] 
                            else x['Merk/Jenis'], 
                            axis=1)
df4['Nama Barang']=df4['Nama Barang'].apply(lambda x:'biskuit' 
                                            if 'roma malkies' in x 
                                            else x)
#pie sand vanilla -> biskuit
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('nan', str(x['Nama Barang'])) 
                            if 'pie sand vanilla' in x['Nama Barang'] 
                            else x['Merk/Jenis'], 
                            axis=1)
df4['Nama Barang']=df4['Nama Barang'].apply(lambda x:'biskuit' 
                                            if 'pie sand vanilla' in x 
                                            else x)
#dovie -> biskuit
df4['Merk/Jenis'] = df4.apply(lambda x: x['Merk/Jenis'].replace(str(x['Merk/Jenis']), str(x['Nama Barang'])) 
                              if 'dovie' in x['Nama Barang'] 
                              else x['Merk/Jenis'],
                              axis=1)
df4['Nama Barang'] = df4['Nama Barang'].apply(lambda x:'biskuit' 
                                              if 'dovie' in x 
                                              else x)
#khong guan red mini -> biskuit
df4['Merk/Jenis'] = df4.apply(lambda x: x['Merk/Jenis'].replace(str(x['Merk/Jenis']), str(x['Nama Barang'])) 
                              if 'khong guan' in x['Nama Barang'] 
                              else x['Merk/Jenis'],
                              axis=1)
df4['Nama Barang'] = df4['Nama Barang'].apply(lambda x:'biskuit' 
                                              if 'khong guan' in x 
                                              else x)
#md cream cracker -> biskuit
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace(str(x['Merk/Jenis']), 'md cream cracker 1200 gr') 
                            if 'md cream cracker' in x['Nama Barang'] 
                            else x['Merk/Jenis'], 
                            axis=1)
df4['Nama Barang'] = df4['Nama Barang'].apply(lambda x:'biskuit' 
                                              if 'md cream cracker' in x 
                                              else x)

# %%
#sabun
df4['Merk/Jenis'] = df4.apply(lambda x: x['Merk/Jenis'].replace('nan', str(x['Nama Barang']).split()[1]) 
                              if 'claudia' in x['Nama Barang'] 
                              else x['Merk/Jenis'],axis=1)
df4['Merk/Jenis'] = df4.apply(lambda x: x['Merk/Jenis'].replace('nan', str(x['Nama Barang']).split()[1]) 
                              if 'marina' in x['Nama Barang'] 
                              else x['Merk/Jenis'], axis=1)
df4['Nama Barang'] = df4['Nama Barang'].apply(lambda x: x.split()[0] 
                                              if 'sabun' in x 
                                              else x)

# %%
#cookies timtam
df4['Merk/Jenis'] = df4.apply(lambda x: x['Merk/Jenis'].replace('16 gram', 'timtam 16 gram').replace('81 gram', 'timtam 81 gram') 
                              if 'cookies timtam' in x['Nama Barang'] 
                              else x['Merk/Jenis'],
                              axis=1)
df4['Merk/Jenis'] = df4.apply(lambda x: x['Merk/Jenis'].replace('nan', 'timtam 81 gram') 
                              if 'cookies timtam' in x['Nama Barang'] 
                              else x['Merk/Jenis'],
                              axis=1)
df4['Merk/Jenis'] = df4.apply(lambda x: x['Merk/Jenis'].replace('timtam 16 gram', 'timtam 81 gram') 
                              if '27.02' in x['Nomor GDN/GRN'] 
                              else x['Merk/Jenis'],axis=1)
df4['Berat Barang'] = df4.apply(lambda x: x['Berat Barang'].replace('nan','0.081').replace('0.016','0.081') 
                                if 'timtam 81 gram' in x['Merk/Jenis'] 
                                else x['Berat Barang'],
                                axis=1)
#cookies
df4['Merk/Jenis'] = df4.apply(lambda x: x['Merk/Jenis'].replace('nan', str(x['Nama Barang']).split(' ',1)[1]) 
                              if 'cookies good time' in x['Nama Barang'] 
                              else x['Merk/Jenis'],
                              axis=1)
df4['Nama Barang'] = df4['Nama Barang'].apply(lambda x: x.split()[0] 
                                              if 'cookies' in x 
                                              else x)
#trendy assortment -> cookies
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('nan', 'nissin' + " " + str(x['Nama Barang'])) 
                            if 'trendy assortment' in x['Nama Barang'] 
                            else x['Merk/Jenis'], 
                            axis=1)
df4['Nama Barang']=df4['Nama Barang'].apply(lambda x:'cookies' 
                                            if 'trendy assortment' in x 
                                            else x)
df4['Berat Barang'] = df4.apply(lambda x: x['Berat Barang'].replace('0.115','0.850').replace('nan','0.850') 
                                if 'nissin trendy assortment' in x['Merk/Jenis'] 
                                else x['Berat Barang'],
                                axis=1)
df4['Nilai'] = df4.apply(lambda x: x['Nilai'].replace('2150','89000').replace('nan','89000') 
                         if 'nissin trendy assortment' in x['Merk/Jenis'] 
                         else x['Nilai'],
                         axis=1)
#harmony assortment -> cookies
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('850 gr','monde' + " " + str(x['Nama Barang'])).replace('nan','monde' + " " + str(x['Nama Barang'])) 
                            if 'harmony assortment' in x['Nama Barang'] 
                            else x['Merk/Jenis'], 
                            axis=1)
df4['Nama Barang']=df4['Nama Barang'].apply(lambda x:'cookies' 
                                            if 'harmony assortment' in x 
                                            else x)

# %%
#tshirt
df4['Merk/Jenis'] = df4.apply(lambda x: x['Merk/Jenis'].replace('nan', str(x['Nama Barang']).split()[1]) 
                              if 'tshirt' in x['Nama Barang'] 
                              else x['Merk/Jenis'],axis=1)
df4['Nama Barang'] = df4['Nama Barang'].apply(lambda x: x.split()[0] 
                                              if 'tshirt' in x 
                                              else x)
df4['Merk/Jenis'] = df4.apply(lambda x: x['Merk/Jenis'].replace('nan', str(x['Nama Barang']).split(' ',1)[1]) 
                              if 't-shirt' in x['Nama Barang'] 
                              else x['Merk/Jenis'],axis=1)
df4['Nama Barang'] = df4['Nama Barang'].apply(lambda x: 'tshirt' 
                                              if 't-shirt' in x 
                                              else x)

# %%
#ventilator
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('sv300', 'sv 300') 
                            if 'ventilator' in x['Nama Barang'] 
                            else x['Merk/Jenis'], axis=1)
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('nan', str(x['Nama Barang']).split(' ',2)[2]) 
                            if 'ventilator type' in x['Nama Barang'] 
                            else x['Merk/Jenis'], axis=1)
df4['Nama Barang'] = df4['Nama Barang'].apply(lambda x: x.split()[0] 
                                              if 'ventilator' 
                                              in x else x)
#asumsi yang nan=sv 300
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('nan','sv 300')
                            if 'ventilator' in x['Nama Barang'] 
                            else x['Merk/Jenis'], axis=1)
df4['Berat Barang']=df4.apply(lambda x: x['Berat Barang'].replace('nan', '33') 
                            if 'sv 300' in x['Merk/Jenis'] 
                            else x['Berat Barang'],
                            axis=1)
df4['Nilai']=df4.apply(lambda x: x['Nilai'].replace('nan', '112420000') 
                            if 'ventilator' in x['Nama Barang'] 
                            else x['Nilai'],
                            axis=1)

# %%
#wafer
df4['Merk/Jenis'] = df4.apply(lambda x: x['Merk/Jenis'].replace('nan', str(x['Nama Barang']).split()[1]) 
                              if 'wafer' in x['Nama Barang'] 
                              else x['Merk/Jenis'],
                              axis=1)
df4['Nama Barang'] = df4['Nama Barang'].apply(lambda x: x.split()[0] 
                                              if 'wafer' in x 
                                              else x)
#popolo -> wafer
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('wafer', str(x['Nama Barang'])) 
                            if 'popolo' in x['Nama Barang'] 
                            else x['Merk/Jenis'], 
                            axis=1)
df4['Nama Barang']=df4['Nama Barang'].apply(lambda x:'wafer' 
                                            if 'popolo' in x 
                                            else x)

# %%
#antigen
df4['Merk/Jenis'] = df4.apply(lambda x: x['Merk/Jenis'].replace('nan', 'antigen roche cov-2') 
                              if 'alat rapid test antigen' in x['Nama Barang'] 
                              else x['Merk/Jenis'],
                              axis=1)

# %%
#snack
df4['Merk/Jenis'] = df4.apply(lambda x: x['Merk/Jenis'].replace('nan', str(x['Nama Barang']).split('snack')[0]+' '+str(x['Nama Barang']).split('snack')[1]) 
                              if 'snack' in x['Nama Barang'] 
                              else x['Merk/Jenis'],
                              axis=1)
df4['Nama Barang'] = df4['Nama Barang'].apply(lambda x: 'snack' 
                                              if 'snack' in x 
                                              else x)
#momogi -> snack
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('nan', str(x['Nama Barang'])) 
                            if 'momogi' in x['Nama Barang'] 
                            else x['Merk/Jenis'], 
                            axis=1)
df4['Nama Barang']=df4['Nama Barang'].apply(lambda x:'snack' 
                                            if 'momogi' in x 
                                            else x)

# %%
#wipol
df4['Merk/Jenis'] = df4.apply(lambda x: x['Merk/Jenis'].replace('nan', '780 ml') 
                              if 'wipol' in x['Nama Barang'] 
                              else x['Merk/Jenis'],axis=1)

# %%
#buavita
df4['Merk/Jenis'] = df4.apply(lambda x: x['Merk/Jenis'].replace('nan', '250 ml') 
                              if 'buavita' in x['Nama Barang'] 
                              else x['Merk/Jenis'],axis=1)
df4['Nilai'] = df4.apply(lambda x: x['Nilai'].replace('5000','5800') 
                         if 'buavita' in x['Nama Barang'] 
                         else x['Nilai'],axis=1)

# %%
#buku-gausah
#df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('nan', str(x['Nama Barang']).split()[1]) if 'buku' in x['Nama Barang'] else x['Merk/Jenis'], axis=1)
#df4['Nama Barang']=df4['Nama Barang'].apply(lambda x:x.split()[0] if 'buku' in x else x)

# %%
#sereal
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('nan', str(x['Nama Barang'])) 
                            if 'cerelac nestle' in x['Nama Barang'] 
                            else x['Merk/Jenis'], 
                            axis=1)
df4['Nama Barang']=df4['Nama Barang'].apply(lambda x:'sereal' 
                                            if 'cerelac nestle' in x 
                                            else x)
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('nan', 'koko krunch') 
                            if 'koko krunch' in x['Nama Barang'] 
                            else x['Merk/Jenis'], 
                            axis=1)
df4['Nama Barang']=df4['Nama Barang'].apply(lambda x:'sereal' 
                                            if 'koko krunch' in x 
                                            else x)
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('nan', str(x['Nama Barang'])) 
                            if 'simba' in x['Nama Barang'] 
                            else x['Merk/Jenis'], 
                            axis=1)
df4['Nama Barang']=df4['Nama Barang'].apply(lambda x:'sereal' 
                                            if 'simba' in x 
                                            else x)
#energen -> sereal
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('nan', str(x['Nama Barang'])) 
                            if 'energen' in x['Nama Barang'] 
                            else x['Merk/Jenis'], 
                            axis=1)
df4['Nama Barang']=df4['Nama Barang'].apply(lambda x:'sereal' 
                                            if 'energen' in x 
                                            else x)

# %%
#hand sanitizer
df4['Satuan'] = df4.apply(lambda x: x['Satuan'].replace('botol', 'jerigen') 
                          if 'hand sanitizer 1 liter' in x['Nama Barang'] 
                          else x['Satuan'],axis=1)
df4['Merk/Jenis'] = df4.apply(lambda x: x['Merk/Jenis'].replace(str(x['Merk/Jenis']), str(x['Nama Barang']).split(" ",2)[2]) 
                              if 'hand sanitizer' in x['Nama Barang'] 
                              else x['Merk/Jenis'],axis=1)
df4['Nama Barang']=df4['Nama Barang'].apply(lambda x: 'hand sanitizer' 
                                            if 'hand sanitizer' in x 
                                            else x)
df4['Merk/Jenis'] = df4.apply(lambda x: x['Merk/Jenis'].replace('meja', 'meja 250 ml').replace('saku','saku 100 ml') 
                              if 'hand sanitizer' in x['Nama Barang'] 
                              else x['Merk/Jenis'],axis=1)
df4['Berat Barang'] = df4.apply(lambda x: x['Berat Barang'].replace('0.1', '0.25') 
                                if 'meja 250 ml' in x['Merk/Jenis'] 
                                else x['Berat Barang'],axis=1)

# %%
#disinfektan
df4['Merk/Jenis'] = df4.apply(lambda x: x['Merk/Jenis'].replace('cap lang', 'spray cap lang') 
                              if 'disinfektan spray' in x['Nama Barang'] 
                              else x['Merk/Jenis'],axis=1)
df4['Merk/Jenis'] = df4.apply(lambda x: x['Merk/Jenis'].replace('nan', str(x['Nama Barang']).split(' ',1)[1]) 
                              if (('disinfektan' in x['Nama Barang'])&('tisu' not in x['Nama Barang'])) 
                              else x['Merk/Jenis'],axis=1)
df4['Nama Barang'] = df4['Nama Barang'].apply(lambda x: x.split()[0] 
                                              if (('disinfektan' in x)&('tisu' not in x))  
                                              else x)

# %%
#gula putih gulare
df4['Merk/Jenis'] = df4.apply(lambda x: x['Merk/Jenis'].replace('nan', str(x['Nama Barang']).split()[2]) 
                              if 'gula putih gulare' in x['Nama Barang'] 
                              else x['Merk/Jenis'],axis=1)
df4['Nama Barang'] = df4['Nama Barang'].apply(lambda x: 'gula putih' 
                                              if 'gula putih gulare' in x 
                                              else x)

# %%
#jas hujan
df4['Merk/Jenis'] = df4.apply(lambda x: x['Merk/Jenis'].replace('nan', '3 layer') 
                              if (('jas hujan' in x['Nama Barang']) & ('121000' in x['Nilai']))
                              else x['Merk/Jenis'],
                              axis=1)

# %%
#kacamata safety (asumsi nan=krisbow)
df4['Merk/Jenis'] = df4.apply(lambda x: x['Merk/Jenis'].replace('nan', 'krisbow').replace('spectacle flesible clear', 'krisbow')
                               if 'kacamata' in x['Nama Barang'] 
                               else x['Merk/Jenis'],
                               axis=1)
df4['Nama Barang'] = df4['Nama Barang'].apply(lambda x: 'kacamata safety' 
                                              if 'kacamata' in x 
                                              else x)

# %%
#kantong mayat
df4['Merk/Jenis'] = df4.apply(lambda x: x['Merk/Jenis'].replace('nan', 'infeksius') 
                              if 'kantong mayat infeksius' in x['Nama Barang'] 
                              else x['Merk/Jenis'],axis=1)
df4['Nama Barang'] = df4['Nama Barang'].apply(lambda x: str(x.split()[0])+' '+str(x.split()[1]) 
                                              if 'kantong mayat' in x 
                                              else x)

# %%
#kecap manis
df4['Merk/Jenis'] = df4.apply(lambda x: x['Merk/Jenis'].replace('nan', 'abc') 
                              if 'kecap manis' in x['Nama Barang'] 
                              else x['Merk/Jenis'],axis=1)

# %%
#kopi
df4['Merk/Jenis'] = df4.apply(lambda x: x['Merk/Jenis'].replace('nan', str(x['Nama Barang']).split(' ',1)[1]) 
                              if 'kopi' in x['Nama Barang'] 
                              else x['Merk/Jenis'],
                              axis=1)
df4['Nama Barang'] = df4['Nama Barang'].apply(lambda x: x.split()[0] 
                                              if 'kopi' in x 
                                              else x)
df4['Berat Barang']=df4.apply(lambda x: x['Berat Barang'].replace('0.12', '0.065') 
                            if 'kapal api' in x['Merk/Jenis'] 
                            else x['Berat Barang'],
                            axis=1)
df4['Nilai']=df4.apply(lambda x: x['Nilai'].replace('nan', '1100') 
                            if 'kapal api' in x['Merk/Jenis'] 
                            else x['Nilai'],
                            axis=1)
#nescafe -> kopi
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace(str(x['Merk/Jenis']), str(x['Nama Barang'])+' '+'220 ml') 
                            if 'nescafe' in x['Nama Barang'] 
                            else x['Merk/Jenis'], 
                            axis=1)
df4['Nama Barang']=df4['Nama Barang'].apply(lambda x:'kopi' 
                                            if 'nescafe' in x 
                                            else x)
df4['Berat Barang']=df4.apply(lambda x: x['Berat Barang'].replace('0.5', '0.22') 
                            if 'nescafe' in x['Merk/Jenis'] 
                            else x['Berat Barang'],
                            axis=1)

# %%
#masker respirator
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('np306', 'np-306') 
                            if 'masker respirator' in x['Nama Barang'] 
                            else x['Merk/Jenis'], axis=1)
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('nan', 'np-306') 
                            if 'masker respirator' in x['Nama Barang'] 
                            else x['Merk/Jenis'], axis=1)

# %%
#mie instan
df4['Merk/Jenis']=df4.apply(lambda x:'indomie' 
                            if 'mie instan' in x['Nama Barang'] 
                            else x['Merk/Jenis'], axis=1)

# %%
#minyak goreng sunco
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('nan', str(x['Nama Barang'].split()[2])) 
                            if 'minyak goreng' in x['Nama Barang'] 
                            else x['Merk/Jenis'], axis=1)
df4['Nama Barang']=df4['Nama Barang'].apply(lambda x:'minyak goreng' 
                                            if 'minyak goreng' in x 
                                            else x)

# %%
#tisu wajah
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('nan', str(x['Nama Barang'].split()[0])) 
                            if 'multi tisu wajah' in x['Nama Barang'] 
                            else x['Merk/Jenis'], axis=1)
df4['Nama Barang']=df4['Nama Barang'].apply(lambda x:'tisu wajah' 
                                            if 'multi tisu wajah' in x 
                                            else x)

# %%
#my baby minyak telon
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('nan', str(x['Nama Barang'].split('minyak')[0])+'plus') 
                            if 'my baby minyak telon' in x['Nama Barang'] 
                            else x['Merk/Jenis'], axis=1)
df4['Nama Barang']=df4['Nama Barang'].apply(lambda x:'minyak telon' 
                                            if 'my baby minyak telon' in x 
                                            else x)

# %%
#rompi pmi
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('biru,merah', 'nan') 
                            if 'rompi pmi' in x['Nama Barang'] 
                            else x['Merk/Jenis'], axis=1)

# %%
#roti
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('nan', str(x['Nama Barang'])) 
                            if 'roti' in x['Nama Barang'] 
                            else x['Merk/Jenis'], axis=1)
df4['Nama Barang']=df4['Nama Barang'].apply(lambda x:'roti' 
                                            if 'roti' in x 
                                            else x)

# %%
#samsung galaxy
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('nan', str(x['Nama Barang'])) 
                            if 'samsung galaxy tab' in x['Nama Barang'] 
                            else x['Merk/Jenis'], axis=1)
df4['Nama Barang']=df4['Nama Barang'].apply(lambda x:'tablet' 
                                            if 'samsung galaxy tab' in x 
                                            else x)

# %%
#sarden
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('nan', 'abc') if 'sarden' 
                            in x['Nama Barang'] 
                            else x['Merk/Jenis'], axis=1)

# %%
#sarung tangan karet
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('nan', 'krisbow') 
                            if 'sarung tangan karet' in x['Nama Barang'] 
                            else x['Merk/Jenis'], axis=1)

# %%
#sikat gigi
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('formula', 'nan') 
                            if 'sikat gigi' in x['Nama Barang'] 
                            else x['Merk/Jenis'], axis=1)

# %%
#sunlight
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('nan', 'sunlight') 
                            if 'sunlight' in x['Nama Barang'] 
                            else x['Merk/Jenis'], axis=1)
df4['Nama Barang']=df4['Nama Barang'].apply(lambda x:'sabun cuci piring' 
                                            if 'sunlight' in x 
                                            else x)

# %%
#teh
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('nan', 'sariwangi') if 'teh celup sariwangi' 
                            in x['Nama Barang'] 
                            else x['Merk/Jenis'], axis=1)
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('nan', str(x['Nama Barang'].split()[1])) 
                            if 'teh poci' in x['Nama Barang'] 
                            else x['Merk/Jenis'], axis=1)
df4['Nama Barang']=df4['Nama Barang'].apply(lambda x:'teh' 
                                            if 'teh' in x 
                                            else x)

# %%
#termometer infrared
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('nan', 'krisbow') 
                            if 'termometer infrared' in x['Nama Barang'] 
                            else x['Merk/Jenis'], axis=1)

# %%
#tisu basah disinfektan
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('nan', 'lapin') 
                            if 'tisu basah disinfektan' in x['Nama Barang'] 
                            else x['Merk/Jenis'], axis=1)
df4['Nilai']=df4.apply(lambda x:x['Nilai'].replace(str(x['Nilai']), '35000') 
                       if 'lapin' in x['Merk/Jenis'] 
                       else x['Nilai'], axis=1)
df4['Berat Barang']=df4.apply(lambda x:x['Berat Barang'].replace(str(x['Berat Barang']), '0.1') 
                              if 'lapin' in x['Merk/Jenis'] 
                              else x['Berat Barang'], axis=1)

# %%
#virkon
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('nan', '2.5 kg').replace('1 kg', '2.5 kg') 
                            if (('virkon' in x['Nama Barang'])&('cair' not in x['Nama Barang'])) 
                            else x['Merk/Jenis'], 
                            axis=1)
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace('nan', 'cair')
                            if 'virkon cair' in x['Nama Barang'] 
                            else x['Merk/Jenis'], 
                            axis=1)
df4['Nama Barang']=df4['Nama Barang'].apply(lambda x:'virkon' 
                                            if 'virkon' in x 
                                            else x)

# %%
#susu
df4['Merk/Jenis']=df4.apply(lambda x:x['Merk/Jenis'].replace(str(x['Merk/Jenis']), 'kental manis') 
                            if 'susu kental manis' in x['Nama Barang'] 
                            else x['Merk/Jenis'], 
                            axis=1)
df4['Nilai']=df4.apply(lambda x:x['Nilai'].replace('nan', '1100') 
                       if 'kental manis' in x['Merk/Jenis'] 
                       else x['Nilai'], 
                       axis=1)
df4['Berat Barang']=df4.apply(lambda x: x['Berat Barang'].replace('nan', '0.37') 
                              if 'kental manis' in x['Merk/Jenis'] 
                              else x['Berat Barang'], 
                              axis=1)
df4['Merk/Jenis']=df4.apply(lambda x: 'vidoran' 
                            if 'vidoran' in x['Nama Barang'] 
                            else x['Merk/Jenis'], 
                            axis=1)
df4['Merk/Jenis']=df4.apply(lambda x: 'bubuk'+' '+str(x['Merk/Jenis']) 
                            if 'bubuk' in x['Nama Barang'] 
                            else x['Merk/Jenis'], 
                            axis=1)
df4['Merk/Jenis']=df4.apply(lambda x: 'beruang' 
                            if 'susu beruang' in x['Nama Barang'] 
                            else x['Merk/Jenis'], 
                            axis=1)
df4['Merk/Jenis']=df4.apply(lambda x: 'vivity' 
                            if 'susu vivity' in x['Nama Barang'] 
                            else x['Merk/Jenis'], 
                            axis=1)
df4['Merk/Jenis']=df4.apply(lambda x: str(x['Nama Barang']) 
                            if 'uht milk' in x['Nama Barang'] 
                            else x['Merk/Jenis'], 
                            axis=1)
df4['Nama Barang']=df4['Nama Barang'].apply(lambda x:'susu' 
                                            if 'susu' in x 
                                            else x)
df4['Nama Barang']=df4['Nama Barang'].apply(lambda x:'susu' 
                                            if 'uht milk' in x 
                                            else x)

# %%
#air mineral (asumsi aja)
df4['Merk/Jenis']=df4.apply(lambda x: x['Merk/Jenis'].replace(str(x['Merk/Jenis']), 'botol 600 ml') 
                            if (('air mineral botol' in x['Nama Barang']) & ('1500' in x['Nilai'])) 
                            else x['Merk/Jenis'], axis=1)
df4['Merk/Jenis']=df4.apply(lambda x: x['Merk/Jenis'].replace(str(x['Merk/Jenis']), 'botol 1500 ml') 
                            if (('air mineral botol' in x['Nama Barang']) & ('4000' in x['Nilai'])) 
                            else x['Merk/Jenis'], axis=1)
df4['Berat Barang']=df4.apply(lambda x: x['Berat Barang'].replace('0.6', '1.5') 
                              if (('botol 1500 ml' in x['Merk/Jenis']) & ('air mineral botol' in x['Nama Barang'])) 
                              else x['Berat Barang'], axis=1)
df4['Nama Barang']=df4['Nama Barang'].apply(lambda x:'air mineral' 
                                            if 'air mineral botol' in x 
                                            else x)

df4['Merk/Jenis']=df4.apply(lambda x: x['Merk/Jenis'].replace(str(x['Merk/Jenis']), 'gelas 220 ml') 
                            if 'air mineral gelas' in x['Nama Barang'] 
                            else x['Merk/Jenis'], axis=1)
df4['Berat Barang']=df4.apply(lambda x: x['Berat Barang'].replace('0.24', '0.22') 
                              if 'gelas 220 ml' in x['Merk/Jenis'] 
                              else x['Berat Barang'], axis=1)
df4['Nama Barang']=df4['Nama Barang'].apply(lambda x:'air mineral' 
                                            if 'air mineral gelas' in x 
                                            else x)

df4['Merk/Jenis']=df4.apply(lambda x: x['Merk/Jenis'].replace('nan', 'galon 5 liter') 
                            if 'air mineral galon' in x['Nama Barang'] 
                            else x['Merk/Jenis'], axis=1)
df4['Nama Barang']=df4['Nama Barang'].apply(lambda x:'air mineral' 
                                            if 'air mineral galon' in x 
                                            else x)

# %%
#food kit
df4['Merk/Jenis']=df4.apply(lambda x: x['Merk/Jenis'].replace('nan', 'roti, air, sari gandum') 
                            if (('food kit' in x['Nama Barang']) & ('0.2' in x['Berat Barang'])) 
                            else x['Merk/Jenis'],
                            axis=1)

# %%
#handuk
df4['Berat Barang']=df4.apply(lambda x: x['Berat Barang'].replace('0.05', '0.3') 
                            if 'handuk' in x['Nama Barang'] 
                            else x['Berat Barang'],
                            axis=1)

# %%
#hazmat
df4['Merk/Jenis']=df4.apply(lambda x: x['Merk/Jenis'].replace(str(x['Merk/Jenis']), 'tyvek') 
                            if 'hazmat' in x['Nama Barang'] 
                            else x['Merk/Jenis'],
                            axis=1)
df4['Berat Barang']=df4.apply(lambda x: x['Berat Barang'].replace('0.25', '0.08') 
                            if 'hazmat' in x['Nama Barang'] 
                            else x['Berat Barang'],
                            axis=1)

# %%
#makanan bayi instan
df4['Berat Barang']=df4.apply(lambda x: x['Berat Barang'].replace('0.05', '0.12') 
                            if 'makanan bayi instan' in x['Nama Barang'] 
                            else x['Berat Barang'],
                            axis=1)

# %%
#kaporit
df4['Merk/Jenis']=df4.apply(lambda x: x['Merk/Jenis'].replace(str(x['Merk/Jenis']), 'tjiwi kimia 15 kg') 
                            if (('kaporit' in x['Nama Barang']) & ('cair' not in x['Nama Barang']))
                            else x['Merk/Jenis'],
                            axis=1)
df4['Berat Barang']=df4.apply(lambda x: x['Berat Barang'].replace('nan', '15') 
                            if 'tjiwi kimia 15 kg' in x['Merk/Jenis'] 
                            else x['Berat Barang'],
                            axis=1)
df4['Merk/Jenis']=df4.apply(lambda x: x['Merk/Jenis'].replace('nan', str(x['Nama Barang']).split()[1]) 
                            if 'kaporit cair' in x['Nama Barang'] 
                            else x['Merk/Jenis'],
                            axis=1)
df4['Nama Barang']=df4['Nama Barang'].apply(lambda x:'kaporit' 
                                            if 'kaporit' in x 
                                            else x)

# %%
#medicated soap
df4['Nama Barang']=df4['Nama Barang'].apply(lambda x:'medicated soap' 
                                            if 'medicated soap' in x 
                                            else x)

# %%
#kompresor set
df4['Merk/Jenis']=df4.apply(lambda x: x['Merk/Jenis'].replace('nan', 'sanchin') 
                            if 'kompresor set' in x['Nama Barang'] 
                            else x['Merk/Jenis'],
                            axis=1)
df4['Berat Barang']=df4.apply(lambda x: x['Berat Barang'].replace('0.025', '60') 
                            if 'sanchin' in x['Merk/Jenis'] 
                            else x['Berat Barang'],
                            axis=1)

# %%
#pembersih lantai karbol
#biosol
df4['Merk/Jenis']=df4.apply(lambda x: x['Merk/Jenis'].replace('nan', 'biosol') 
                            if 'biosol' in x['Nama Barang'] 
                            else x['Merk/Jenis'],
                            axis=1)
df4['Nama Barang']=df4['Nama Barang'].apply(lambda x:'pembersih lantai karbol' 
                                            if 'biosol' in x 
                                            else x)
#wipol
df4['Merk/Jenis']=df4.apply(lambda x: 'wipol 780 ml' 
                            if (('wipol' in x['Nama Barang']) & ('0.78' in x['Berat Barang']))
                            else x['Merk/Jenis'],
                            axis=1)
df4['Nama Barang']=df4['Nama Barang'].apply(lambda x:'pembersih lantai karbol' 
                                            if 'wipol' in x 
                                            else x)

# %%
#panduan ctps
df4['Merk/Jenis'] = df4.apply(lambda x: x['Merk/Jenis'].replace('nan', str(x['Nama Barang'])) 
                              if 'panduan ctps' in x['Nama Barang'] 
                              else x['Merk/Jenis'],
                              axis=1)
df4['Nama Barang']=df4['Nama Barang'].apply(lambda x:'panduan ctps' 
                                            if 'panduan ctps' in x 
                                            else x)

# %%
#faceshield
df4['Merk/Jenis'] = df4.apply(lambda x: x['Merk/Jenis'].replace('nan', 'mika plastik') 
                              if 'face shield' in x['Nama Barang'] 
                              else x['Merk/Jenis'],
                              axis=1)

# %%
df4.head()
# Out:
#      Tanggal IN/OUT Nomor GDN/GRN Gudang                 Dari/Kepada  \
# 0 2020-02-01     IN         01.01     G2  Gudang Regional PMI_Serang
# 1 2020-02-01    OUT         01.01     G2                  Ketua Umum
# 2 2020-02-01    OUT         01.02     G2        PMI Kabupaten Natuna
# 3 2020-02-05    OUT         05.01     G2       Palang Merah Hongkong
# 4 2020-02-05    OUT         05.02     G2                   Lain-lain
#
#     Nama Barang Merk/Jenis Satuan     Masuk   Keluar     Nilai        Jumlah  \
# 0  masker bedah      sensi    Pcs  350000.0      NaN    7000.0  2.450000e+09
# 1    masker n95         3m    Pcs       NaN    800.0  108240.0  8.659200e+07
# 2  masker bedah      sensi    Pcs       NaN  20000.0    7000.0  1.400000e+08
# 3  masker bedah      sensi    Pcs       NaN  50000.0    7000.0  3.500000e+08
# 4  masker bedah      sensi    Pcs       NaN   4000.0    7000.0  2.800000e+07
#
#   Berat Barang  Total Berat Barang
# 0        0.006              2100.0
# ...

# %%
nama_barang = df4['Nama Barang'].unique()
print(sorted(nama_barang))
# Out:
# ['air mineral', 'alat rapid test', 'alat rapid test antigen', 'apron', 'baby shirt', 'baliho', 'banner 1x3 m', 'bantal', 'beras', 'biskuit', 'boat 380 win merah', 'boneka', 'buavita', 'bubur sun', 'buku gdn', 'buku grn', 'cookies', 'dayung', 'detergen', 'disinfektan', 'face shield', 'family kit', 'fine choco chocolate drink', 'food kit', 'form request', 'gula putih', 'hand sanitizer', 'handuk', 'hansaplast', 'hazmat', 'head cap', 'helm', 'hit aerosol', 'hygiene kit', 'jas hujan', 'jerigen 20 liter', 'kacamata safety', 'kantong mayat', 'kaporit', 'kecap manis', 'kemeja putih', 'knapsack', 'kompresor set', 'kopi', 'lady clothes', 'leaflet', 'life jacket', 'makanan bayi instan', 'masker bedah', 'masker kain', 'masker n95', 'masker respirator', 'matras gulung', 'medicated soap', 'mie instan', 'minyak goreng', 'minyak telon', 'mukena', 'obat ', 'pakaian', 'pakaian anak anak', 'pakaian dalam wanita', 'pakaian h&m', 'pakaian wanita', 'paket karyawan pmi', 'paket lebaran', 'paket phbs', 'pak
# ...

# %%
df4['Nama Barang'] = df4['Nama Barang'].apply(lambda x: x.lower().strip())
df4['Merk/Jenis'] = df4['Merk/Jenis'].apply(lambda x: x.lower().strip())

# %%
kelompok = {"air mineral" : "minuman", "alat rapid test" : "peralatan medis",
            "alat rapid test antigen" : "peralatan medis", "apron" : "alat pelindung diri",
            "baby shirt" : "pakaian", 'baliho':'media informasi',
            'banner 1x3 m':'media informasi', 'bantal':'perlengkapan istirahat',
            'beras':'makanan',
            'biskuit':'makanan', 'boat 380 win merah':'peralatan penanganan bencana',
            'boneka':'other', 'buavita':'minuman',
            'bubur sun':'makanan', 'buku gdn':'media informasi',
            'buku grn':'media informasi', 'cookies':'makanan',
            'dayung':'peralatan penanganan bencana', 'detergen':'bahan kimia',
            'disinfektan':'bahan kimia', 'face shield':'alat pelindung diri',
            'family kit':'paket bantuan', 'fine choco chocolate drink':'minuman',
            'food kit':'paket bantuan', 'form request':'other',
            'gula putih':'makanan', 'hand sanitizer':'bahan kimia',
            'handuk':'kebutuhan mck', 'hansaplast':'obat & suplemen',
            'hazmat':'alat pelindung diri', 'head cap':'alat pelindung diri',
            'helm':'alat pelindung diri', 'hit aerosol': 'bahan kimia',
            'hygiene kit':'paket bantuan', 'jas hujan':'alat pelindung diri',
            'jerigen 20 liter':'peralatan umum', 'kacamata safety':'alat pelindung diri',
            'kantong mayat':'peralatan medis', 'kaporit':'bahan kimia',
            'kecap manis':'makanan', 'kemeja putih':'pakaian',
            'knapsack':'peralatan umum', 'kompresor set':'peralatan umum',
            'kopi':'minuman', 'lady clothes':'pakaian',
            'leaflet':'media informasi', 'life jacket':'alat pelindung diri',
            'makanan bayi instan':'makanan', 'masker bedah':'alat pelindung diri',
            'masker kain':'alat pelindung diri', 'masker n95':'alat pelindung diri',
            'masker respirator':'alat pelindung diri', 'matras gulung':'perlengkapan istirahat',
            'medicated soap':'kebutuhan mck', 'mie instan':'makanan',
            'minyak goreng':'makanan', 'minyak telon':'obat & suplemen',
            'mukena':'pakaian', 'obat':'obat & suplemen',
            'pakaian':'pakaian', 'pakaian anak anak':'pakaian',
            'pakaian dalam wanita':'pakaian', 'pakaian h&m':'pakaian',
            'pakaian wanita':'pakaian', 'paket karyawan pmi':'paket bantuan',
            'paket lebaran':'paket bantuan', 'paket phbs':'paket bantuan',
            'paket sembako':'paket bantuan', 'paket steps kids':'paket bantuan',
            'pamflet':'media informasi',  'panduan ctps':'media informasi',
            'paper bag phbs':'paket bantuan', 
            'pasta gigi':'kebutuhan mck', 'pembalut':'kebutuhan mck', 
            'pembersih lantai karbol':'bahan kimia',
            'perlengkapan bayi':'kebutuhan mck', 'pisau lipat multiguna':'peralatan umum', 
            'popok bayi':'kebutuhan mck', 'popok bayi renceng':'kebutuhan mck', 
            'poster':'media informasi', 'river kit':'paket bantuan', 
            'rompi pmi':'pakaian', 'roti':'makanan', 
            'sabun':'kebutuhan mck', 'sabun cuci piring':'kebutuhan mck', 
            'sandal & sepatu':'pakaian', 'saos sambal':'makanan', 
            'sarden':'makanan', 'sarung':'pakaian', 
            'sarung tangan karet':'alat pelindung diri', 'sarung tangan latex':'alat pelindung diri', 
            'sejadah':'pakaian', 'selang':'peralatan umum', 
            'selimut':'pakaian', 'sepatu boot':'alat pelindung diri',
            'sereal':'makanan', 'shampo':'kebutuhan mck',
            'shoes cover':'alat pelindung diri', 'sikat gigi':'kebutuhan mck',
            'snack':'makanan', 'spray gun':'peralatan umum',
            'sprayer':'peralatan umum', 'sprei':'perlengkapan istirahat',
            'stiker cuci tangan':'media informasi', 'suplemen':'obat & suplemen',
            'susu':'minuman', 'tablet':'barang elektronik',
            'tandon air 300 lt':'kebutuhan mck', 'teh':'minuman', 
            'termometer infrared':'peralatan medis', 'terpal':'peralatan umum',
            'tikar':'perlengkapan istirahat', 'tisu basah':'kebutuhan mck',
            'tisu basah disinfektan':'bahan kimia', 'tisu wajah':'kebutuhan mck',
            'tripod poster':'media informasi', 'tshirt':'pakaian',
            'underware pria':'pakaian', 'underware wanita':'pakaian',
            'usg lumify system':'peralatan medis', 'ventilator':'peralatan medis',
            'virkon':'bahan kimia','vitamin':'obat & suplemen', 
            'wafer':'makanan','wastafel':'peralatan umum'
           }

df4["Kelompok Barang"] = df4["Nama Barang"].map(kelompok).astype(str)
df4
# Out:
#         Tanggal IN/OUT Nomor GDN/GRN Gudang                     Dari/Kepada  \
# 0    2020-02-01     IN         01.01     G2      Gudang Regional PMI_Serang
# 1    2020-02-01    OUT         01.01     G2                      Ketua Umum
# 2    2020-02-01    OUT         01.02     G2            PMI Kabupaten Natuna
# 3    2020-02-05    OUT         05.01     G2           Palang Merah Hongkong
# 4    2020-02-05    OUT         05.02     G2                       Lain-lain
# ...         ...    ...           ...    ...                             ...
# 8184 2021-04-26    OUT             -     G4  Tidak Layak digunakan (Reject)
# 8185 2021-04-26    OUT             -     G4  Tidak Layak digunakan (Reject)
# 8186 2021-04-26    OUT             -     G4  Tidak Layak digunakan (Reject)
# 8187 2021-04-27    OUT         27.01     G4                    Staff MP PMI
# 8188 2021-04-27    OUT         27.01     G4                    Staff MP PMI
#
# ...

# %%
df5 = df4.copy()
df5['Berat Barang'] = df5['Berat Barang'].astype(float)
df5['Nilai'] = df5['Nilai'].astype(float)
df5['Masuk'] = df5['Masuk'].astype(float)
df5['Keluar'] = df5['Keluar'].astype(float) * (-1)

df5['Jumlah'] = df5.apply(lambda x: (x['Masuk']*x['Nilai']
                          if x['IN/OUT']=='IN' 
                                     else x['Keluar']*x['Nilai']),
                          axis=1)
df5['Total Berat Barang'] = df5.apply(lambda x: (x['Masuk']*x['Berat Barang']
                          if x['IN/OUT']=='IN' 
                                     else x['Keluar']*x['Berat Barang']),
                          axis=1)
df5.head(10)
# Out:
#      Tanggal IN/OUT Nomor GDN/GRN Gudang                 Dari/Kepada  \
# 0 2020-02-01     IN         01.01     G2  Gudang Regional PMI_Serang
# 1 2020-02-01    OUT         01.01     G2                  Ketua Umum
# 2 2020-02-01    OUT         01.02     G2        PMI Kabupaten Natuna
# 3 2020-02-05    OUT         05.01     G2       Palang Merah Hongkong
# 4 2020-02-05    OUT         05.02     G2                   Lain-lain
# 5 2020-02-05    OUT         05.02     G2                   Lain-lain
# 6 2020-02-05    OUT         05.03     G2                Staff MP PMI
# 7 2020-02-11    OUT         11.01     G2                    Individu
# 8 2020-02-12    OUT         12.01     G2                    Individu
# 9 2020-02-14    OUT         14.01     G2                Staff MP PMI
#
#     Nama Barang Merk/Jenis Satuan     Masuk   Keluar     Nilai        Jumlah  \
# 0  masker bedah      sensi    Pcs  350000.0      NaN    7000.0  2.450000e+09
# ...

# %%
df6 = df4.copy()
df6['Berat Barang'] = df6['Berat Barang'].astype(float)
df6['Nilai'] = df6['Nilai'].astype(float)
df6 = df6.groupby(['Kelompok Barang', 'Nama Barang', 'Merk/Jenis']).agg({'Nilai':[np.mean,np.min,np.median,np.max],
                                                      
                                                      'Berat Barang':[np.mean,np.min,np.median,np.max]})
pd.set_option("max_rows", None)
df6
# Out:
#                                                                                             Nilai  \
#                                                                                              mean
# Kelompok Barang              Nama Barang                Merk/Jenis
# alat pelindung diri          apron                      plastik disposable           7.150000e+03
#                              face shield                mika plastik                 3.150000e+04
#                              hazmat                     tyvek                        2.750000e+05
#                              head cap                   nan                          2.500000e+03
#                              helm                       nan                                   NaN
#                              jas hujan                  3 layer                      1.210000e+05
#                                                         coverall                     2.750000e+05
# ...

# %%
df5.to_excel('dataset_4.xlsx', index=False)
